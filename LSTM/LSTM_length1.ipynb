# %%
import pandas as pd

# %%
df = pd.read_csv('../data/price.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-12-03  46.115002  46.235001  45.302502  46.205002  44.595947
# 1  2018-12-04  45.237499  45.597500  44.067501  44.172501  42.634228
# 2  2018-12-06  42.939999  43.695000  42.605000  43.680000  42.158878
# 3  2018-12-07  43.372501  43.622501  42.075001  42.122501  40.655613
# 4  2018-12-10  41.250000  42.522499  40.832500  42.400002  40.923454
#
#       Volume Ticker
# 0  163210000   AAPL
# 1  165377200   AAPL
# 2  172393600   AAPL
# 3  169126400   AAPL
# 4  248104000   AAPL

# %%
df = df.loc[df['Ticker']=='AAPL']
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-12-03   46.115002   46.235001   45.302502   46.205002   44.595947
# 1     2018-12-04   45.237499   45.597500   44.067501   44.172501   42.634228
# 2     2018-12-06   42.939999   43.695000   42.605000   43.680000   42.158878
# 3     2018-12-07   43.372501   43.622501   42.075001   42.122501   40.655613
# 4     2018-12-10   41.250000   42.522499   40.832500   42.400002   40.923454
# ...          ...         ...         ...         ...         ...         ...
# 1003  2022-11-28  145.139999  146.639999  143.380005  144.220001  144.220001
# 1004  2022-11-29  144.289993  144.809998  140.350006  141.169998  141.169998
# 1005  2022-11-30  141.399994  148.720001  140.550003  148.029999  148.029999
# 1006  2022-12-01  148.210007  149.130005  146.610001  148.309998  148.309998
# 1007  2022-12-02  145.960007  148.000000  145.650101  147.809998  147.809998
#
#          Volume Ticker
# 0     163210000   AAPL
# 1     165377200   AAPL
# 2     172393600   AAPL
# 3     169126400   AAPL
# 4     248104000   AAPL
# ...         ...    ...
# 1003   69246000   AAPL
# 1004   83763800   AAPL
# 1005  111380900   AAPL
# 1006   71250400   AAPL
# 1007   62231328   AAPL
#
# [1008 rows x 8 columns]

# %%
df = df[["Date", "Close"]]
df
# Out:
#             Date       Close
# 0     2018-12-03   46.205002
# 1     2018-12-04   44.172501
# 2     2018-12-06   43.680000
# 3     2018-12-07   42.122501
# 4     2018-12-10   42.400002
# ...          ...         ...
# 1003  2022-11-28  144.220001
# 1004  2022-11-29  141.169998
# 1005  2022-11-30  148.029999
# 1006  2022-12-01  148.309998
# 1007  2022-12-02  147.809998
#
# [1008 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2022-10-16')
datetime_object
# Out:
# datetime.datetime(2022, 10, 16, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /tmp/ipykernel_196689/2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      2018-12-03
# 1      2018-12-04
# 2      2018-12-06
# 3      2018-12-07
# 4      2018-12-10
#           ...
# 1003   2022-11-28
# 1004   2022-11-29
# 1005   2022-11-30
# 1006   2022-12-01
# 1007   2022-12-02
# Name: Date, Length: 1008, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2018-12-03   46.205002
# 2018-12-04   44.172501
# 2018-12-06   43.680000
# 2018-12-07   42.122501
# 2018-12-10   42.400002
# ...                ...
# 2022-11-28  144.220001
# 2022-11-29  141.169998
# 2022-11-30  148.029999
# 2022-12-01  148.309998
# 2022-12-02  147.809998
#
# [1008 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

sequential_length = 1
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2018-12-10', 
                                '2022-12-01', 
                                n=sequential_length)
windowed_df
# Out:
#      Target Date    Target-1      Target
# 0     2018-12-10   42.122501   42.400002
# 1     2018-12-11   42.400002   42.157501
# 2     2018-12-12   42.157501   42.275002
# 3     2018-12-13   42.275002   42.737499
# 4     2018-12-14   42.737499   41.369999
# ...          ...         ...         ...
# 998   2022-11-25  151.070007  148.110001
# 999   2022-11-28  148.110001  144.220001
# 1000  2022-11-29  144.220001  141.169998
# 1001  2022-11-30  141.169998  148.029999
# 1002  2022-12-01  148.029999  148.309998
#
# [1003 rows x 3 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((1003,), (1003, 1, 1), (1003,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((sequential_length, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200)
# Out:
# 2023-01-14 19:46:26.200162: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-14 19:46:26.532362: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-14 19:46:26.532383: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-14 19:46:27.682727: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-14 19:46:27.682800: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-14 19:46:27.682809: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-01-14 19:46:28.977619: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-01-14 19:46:28.977651: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-14 19:46:28.977687: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (quoctrung): /proc/driver/nvidia/version does not exist
# 2023-01-14 19:46:28.977958: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 26/26 [==============================] - 3s 18ms/step - loss: 11097.0371 - mean_absolute_error: 96.6800 - val_loss: 23564.0781 - val_mean_absolute_error: 152.9425
# Epoch 2/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10349.0488 - mean_absolute_error: 92.6915 - val_loss: 21449.5859 - val_mean_absolute_error: 145.8667
# Epoch 3/200
# 26/26 [==============================] - 0s 3ms/step - loss: 8392.6973 - mean_absolute_error: 81.4205 - val_loss: 16578.2246 - val_mean_absolute_error: 128.0837
# Epoch 4/200
# 26/26 [==============================] - 0s 3ms/step - loss: 4827.1250 - mean_absolute_error: 56.2331 - val_loss: 8179.3394 - val_mean_absolute_error: 89.4979
# Epoch 5/200
# 26/26 [==============================] - 0s 3ms/step - loss: 1897.1902 - mean_absolute_error: 36.4713 - val_loss: 3278.2993 - val_mean_absolute_error: 55.7649
# Epoch 6/200
# 26/26 [==============================] - 0s 3ms/step - loss: 1248.0753 - mean_absolute_error: 31.9695 - val_loss: 2597.3320 - val_mean_absolute_error: 49.5438
# Epoch 7/200
# 26/26 [==============================] - 0s 6ms/step - loss: 612.9255 - mean_absolute_error: 20.8279 - val_loss: 1163.1328 - val_mean_absolute_error: 32.2521
# Epoch 8/200
# 26/26 [==============================] - 0s 5ms/step - loss: 189.8183 - mean_absolute_error: 9.5806 - val_loss: 394.4983 - val_mean_absolute_error: 17.3777
# Epoch 9/200
# 26/26 [==============================] - 0s 5ms/step - loss: 92.9071 - mean_absolute_error: 7.0531 - val_loss: 167.2116 - val_mean_absolute_error: 10.4922
# Epoch 10/200
# 26/26 [==============================] - 0s 5ms/step - loss: 78.4611 - mean_absolute_error: 6.8218 - val_loss: 168.3251 - val_mean_absolute_error: 10.6438
# Epoch 11/200
# 26/26 [==============================] - 0s 4ms/step - loss: 55.5289 - mean_absolute_error: 5.6533 - val_loss: 133.6242 - val_mean_absolute_error: 9.4376
# Epoch 12/200
# 26/26 [==============================] - 0s 7ms/step - loss: 46.6082 - mean_absolute_error: 5.0974 - val_loss: 115.7603 - val_mean_absolute_error: 8.8096
# Epoch 13/200
# 26/26 [==============================] - 0s 6ms/step - loss: 40.7375 - mean_absolute_error: 4.7535 - val_loss: 109.4359 - val_mean_absolute_error: 8.6182
# Epoch 14/200
# 26/26 [==============================] - 0s 6ms/step - loss: 33.6755 - mean_absolute_error: 4.2261 - val_loss: 115.6834 - val_mean_absolute_error: 9.0530
# Epoch 15/200
# 26/26 [==============================] - 0s 5ms/step - loss: 30.4582 - mean_absolute_error: 4.0436 - val_loss: 177.0224 - val_mean_absolute_error: 11.9659
# Epoch 16/200
# 26/26 [==============================] - 0s 5ms/step - loss: 47.1080 - mean_absolute_error: 5.0998 - val_loss: 48.7183 - val_mean_absolute_error: 5.7760
# Epoch 17/200
# 26/26 [==============================] - 0s 5ms/step - loss: 24.7540 - mean_absolute_error: 3.5639 - val_loss: 70.7815 - val_mean_absolute_error: 6.9309
# Epoch 18/200
# 26/26 [==============================] - 0s 3ms/step - loss: 20.0784 - mean_absolute_error: 3.1260 - val_loss: 49.6020 - val_mean_absolute_error: 5.7106
# Epoch 19/200
# 26/26 [==============================] - 0s 5ms/step - loss: 17.5746 - mean_absolute_error: 2.8557 - val_loss: 40.9497 - val_mean_absolute_error: 5.1802
# Epoch 20/200
# 26/26 [==============================] - 0s 3ms/step - loss: 16.0449 - mean_absolute_error: 2.6987 - val_loss: 56.2307 - val_mean_absolute_error: 6.2423
# Epoch 21/200
# 26/26 [==============================] - 0s 3ms/step - loss: 13.7285 - mean_absolute_error: 2.4963 - val_loss: 34.2420 - val_mean_absolute_error: 4.7600
# Epoch 22/200
# 26/26 [==============================] - 0s 3ms/step - loss: 13.4356 - mean_absolute_error: 2.5242 - val_loss: 34.8524 - val_mean_absolute_error: 4.8329
# Epoch 23/200
# 26/26 [==============================] - 0s 3ms/step - loss: 11.6824 - mean_absolute_error: 2.2441 - val_loss: 70.6253 - val_mean_absolute_error: 7.2847
# Epoch 24/200
# 26/26 [==============================] - 0s 5ms/step - loss: 15.7210 - mean_absolute_error: 2.8648 - val_loss: 24.1050 - val_mean_absolute_error: 4.0503
# Epoch 25/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.7665 - mean_absolute_error: 2.2212 - val_loss: 35.6228 - val_mean_absolute_error: 4.9594
# Epoch 26/200
# 26/26 [==============================] - 0s 3ms/step - loss: 11.7031 - mean_absolute_error: 2.3821 - val_loss: 70.1617 - val_mean_absolute_error: 7.3359
# Epoch 27/200
# 26/26 [==============================] - 0s 6ms/step - loss: 16.0836 - mean_absolute_error: 2.9436 - val_loss: 40.4929 - val_mean_absolute_error: 5.3751
# Epoch 28/200
# 26/26 [==============================] - 0s 6ms/step - loss: 16.7711 - mean_absolute_error: 3.1586 - val_loss: 44.7957 - val_mean_absolute_error: 5.7018
# Epoch 29/200
# 26/26 [==============================] - 0s 4ms/step - loss: 10.1600 - mean_absolute_error: 2.2313 - val_loss: 21.4599 - val_mean_absolute_error: 3.8043
# Epoch 30/200
# 26/26 [==============================] - 0s 4ms/step - loss: 10.6064 - mean_absolute_error: 2.2889 - val_loss: 30.5055 - val_mean_absolute_error: 4.6290
# Epoch 31/200
# 26/26 [==============================] - 0s 8ms/step - loss: 11.1461 - mean_absolute_error: 2.3762 - val_loss: 19.5217 - val_mean_absolute_error: 3.6331
# Epoch 32/200
# 26/26 [==============================] - 0s 6ms/step - loss: 8.3793 - mean_absolute_error: 1.9732 - val_loss: 19.1241 - val_mean_absolute_error: 3.5992
# Epoch 33/200
# 26/26 [==============================] - 0s 5ms/step - loss: 8.2760 - mean_absolute_error: 2.0120 - val_loss: 22.8355 - val_mean_absolute_error: 3.9642
# Epoch 34/200
# 26/26 [==============================] - 0s 6ms/step - loss: 9.0047 - mean_absolute_error: 2.1506 - val_loss: 22.4551 - val_mean_absolute_error: 3.9426
# Epoch 35/200
# 26/26 [==============================] - 0s 6ms/step - loss: 7.4676 - mean_absolute_error: 1.8788 - val_loss: 23.6055 - val_mean_absolute_error: 4.0729
# Epoch 36/200
# 26/26 [==============================] - 0s 6ms/step - loss: 8.4999 - mean_absolute_error: 2.1147 - val_loss: 16.9536 - val_mean_absolute_error: 3.3069
# Epoch 37/200
# 26/26 [==============================] - 0s 5ms/step - loss: 9.2944 - mean_absolute_error: 2.2472 - val_loss: 16.2545 - val_mean_absolute_error: 3.2739
# Epoch 38/200
# 26/26 [==============================] - 0s 5ms/step - loss: 9.8897 - mean_absolute_error: 2.3329 - val_loss: 16.6862 - val_mean_absolute_error: 3.2633
# Epoch 39/200
# 26/26 [==============================] - 0s 3ms/step - loss: 8.7400 - mean_absolute_error: 2.1255 - val_loss: 37.8357 - val_mean_absolute_error: 5.0068
# Epoch 40/200
# 26/26 [==============================] - 0s 5ms/step - loss: 11.6195 - mean_absolute_error: 2.6089 - val_loss: 56.0392 - val_mean_absolute_error: 6.6025
# Epoch 41/200
# 26/26 [==============================] - 0s 5ms/step - loss: 10.0848 - mean_absolute_error: 2.3342 - val_loss: 16.4311 - val_mean_absolute_error: 3.2209
# Epoch 42/200
# 26/26 [==============================] - 0s 4ms/step - loss: 7.6406 - mean_absolute_error: 1.9523 - val_loss: 15.4483 - val_mean_absolute_error: 3.2089
# Epoch 43/200
# 26/26 [==============================] - 0s 6ms/step - loss: 6.8039 - mean_absolute_error: 1.8290 - val_loss: 15.2692 - val_mean_absolute_error: 3.1562
# Epoch 44/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.4942 - mean_absolute_error: 1.8500 - val_loss: 23.7104 - val_mean_absolute_error: 4.1423
# Epoch 45/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.9113 - mean_absolute_error: 1.8541 - val_loss: 19.8370 - val_mean_absolute_error: 3.7723
# Epoch 46/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.3459 - mean_absolute_error: 1.9348 - val_loss: 36.2238 - val_mean_absolute_error: 5.2091
# Epoch 47/200
# 26/26 [==============================] - 0s 3ms/step - loss: 8.9716 - mean_absolute_error: 2.1856 - val_loss: 14.8081 - val_mean_absolute_error: 3.1237
# Epoch 48/200
# 26/26 [==============================] - 0s 5ms/step - loss: 6.1856 - mean_absolute_error: 1.7504 - val_loss: 14.9262 - val_mean_absolute_error: 3.0646
# Epoch 49/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.0425 - mean_absolute_error: 1.6908 - val_loss: 15.2938 - val_mean_absolute_error: 3.2595
# Epoch 50/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.3366 - mean_absolute_error: 1.7821 - val_loss: 19.6814 - val_mean_absolute_error: 3.7856
# Epoch 51/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.4918 - mean_absolute_error: 1.8365 - val_loss: 15.4365 - val_mean_absolute_error: 3.0432
# Epoch 52/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.7148 - mean_absolute_error: 1.6771 - val_loss: 14.1175 - val_mean_absolute_error: 3.0142
# Epoch 53/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.8084 - mean_absolute_error: 1.9226 - val_loss: 14.1191 - val_mean_absolute_error: 3.0099
# Epoch 54/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.7101 - mean_absolute_error: 1.8643 - val_loss: 19.8770 - val_mean_absolute_error: 3.4532
# Epoch 55/200
# 26/26 [==============================] - 0s 6ms/step - loss: 7.6621 - mean_absolute_error: 1.9991 - val_loss: 21.4311 - val_mean_absolute_error: 3.5893
# Epoch 56/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.8057 - mean_absolute_error: 2.4628 - val_loss: 18.0672 - val_mean_absolute_error: 3.5948
# Epoch 57/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.7279 - mean_absolute_error: 2.0053 - val_loss: 21.6544 - val_mean_absolute_error: 3.9811
# Epoch 58/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.2752 - mean_absolute_error: 1.7826 - val_loss: 18.4280 - val_mean_absolute_error: 3.6640
# Epoch 59/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.2118 - mean_absolute_error: 1.7847 - val_loss: 20.8111 - val_mean_absolute_error: 3.9075
# Epoch 60/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.9813 - mean_absolute_error: 1.7006 - val_loss: 85.0874 - val_mean_absolute_error: 8.4162
# Epoch 61/200
# 26/26 [==============================] - 0s 5ms/step - loss: 14.6921 - mean_absolute_error: 2.9435 - val_loss: 19.7137 - val_mean_absolute_error: 3.4414
# Epoch 62/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.9034 - mean_absolute_error: 2.0640 - val_loss: 14.6637 - val_mean_absolute_error: 3.1812
# Epoch 63/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.1308 - mean_absolute_error: 1.7342 - val_loss: 27.4313 - val_mean_absolute_error: 4.4980
# Epoch 64/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.6595 - mean_absolute_error: 1.8499 - val_loss: 14.0766 - val_mean_absolute_error: 2.9735
# Epoch 65/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.3570 - mean_absolute_error: 1.6266 - val_loss: 13.5993 - val_mean_absolute_error: 3.0108
# Epoch 66/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.5495 - mean_absolute_error: 1.6414 - val_loss: 13.9236 - val_mean_absolute_error: 2.9490
# Epoch 67/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.5801 - mean_absolute_error: 1.6711 - val_loss: 13.7699 - val_mean_absolute_error: 3.0835
# Epoch 68/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.7762 - mean_absolute_error: 1.6930 - val_loss: 24.2826 - val_mean_absolute_error: 3.8448
# Epoch 69/200
# 26/26 [==============================] - 0s 4ms/step - loss: 6.2813 - mean_absolute_error: 1.7668 - val_loss: 15.1023 - val_mean_absolute_error: 3.0143
# Epoch 70/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.0259 - mean_absolute_error: 1.5671 - val_loss: 13.2517 - val_mean_absolute_error: 2.9668
# Epoch 71/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.6113 - mean_absolute_error: 1.6546 - val_loss: 13.7084 - val_mean_absolute_error: 3.0843
# Epoch 72/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.5982 - mean_absolute_error: 2.0373 - val_loss: 14.1344 - val_mean_absolute_error: 2.9535
# Epoch 73/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.9880 - mean_absolute_error: 1.9153 - val_loss: 39.7032 - val_mean_absolute_error: 5.4912
# Epoch 74/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.8777 - mean_absolute_error: 2.0654 - val_loss: 13.3635 - val_mean_absolute_error: 2.9324
# Epoch 75/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.8354 - mean_absolute_error: 1.6920 - val_loss: 14.4398 - val_mean_absolute_error: 2.9685
# Epoch 76/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.6643 - mean_absolute_error: 1.6631 - val_loss: 26.0541 - val_mean_absolute_error: 4.0224
# Epoch 77/200
# 26/26 [==============================] - 0s 3ms/step - loss: 14.2286 - mean_absolute_error: 2.9178 - val_loss: 25.4860 - val_mean_absolute_error: 3.9599
# Epoch 78/200
# 26/26 [==============================] - 0s 3ms/step - loss: 9.7048 - mean_absolute_error: 2.2942 - val_loss: 49.9516 - val_mean_absolute_error: 6.0735
# Epoch 79/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.3103 - mean_absolute_error: 2.3399 - val_loss: 13.5270 - val_mean_absolute_error: 3.0303
# Epoch 80/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.2259 - mean_absolute_error: 1.7722 - val_loss: 13.7390 - val_mean_absolute_error: 3.0798
# Epoch 81/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.7218 - mean_absolute_error: 1.6607 - val_loss: 13.6622 - val_mean_absolute_error: 2.9283
# Epoch 82/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.6768 - mean_absolute_error: 1.6881 - val_loss: 34.1405 - val_mean_absolute_error: 4.7885
# Epoch 83/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.6406 - mean_absolute_error: 2.0426 - val_loss: 25.6398 - val_mean_absolute_error: 3.9806
# Epoch 84/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.6573 - mean_absolute_error: 1.8720 - val_loss: 13.3970 - val_mean_absolute_error: 2.9221
# Epoch 85/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.8408 - mean_absolute_error: 1.6814 - val_loss: 23.0836 - val_mean_absolute_error: 3.7379
# Epoch 86/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.6823 - mean_absolute_error: 1.8850 - val_loss: 34.1577 - val_mean_absolute_error: 4.7917
# Epoch 87/200
# 26/26 [==============================] - 0s 3ms/step - loss: 11.9716 - mean_absolute_error: 2.6827 - val_loss: 14.1866 - val_mean_absolute_error: 2.9618
# Epoch 88/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.9526 - mean_absolute_error: 1.7274 - val_loss: 18.3787 - val_mean_absolute_error: 3.2849
# Epoch 89/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.8833 - mean_absolute_error: 1.7184 - val_loss: 31.6908 - val_mean_absolute_error: 4.8626
# Epoch 90/200
# 26/26 [==============================] - 0s 3ms/step - loss: 8.4988 - mean_absolute_error: 2.1628 - val_loss: 18.4985 - val_mean_absolute_error: 3.6931
# Epoch 91/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.8172 - mean_absolute_error: 1.6623 - val_loss: 13.1639 - val_mean_absolute_error: 2.9828
# Epoch 92/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.2461 - mean_absolute_error: 1.5797 - val_loss: 28.9765 - val_mean_absolute_error: 4.3069
# Epoch 93/200
# 26/26 [==============================] - 0s 5ms/step - loss: 11.3490 - mean_absolute_error: 2.6228 - val_loss: 18.1957 - val_mean_absolute_error: 3.2699
# Epoch 94/200
# 26/26 [==============================] - 0s 3ms/step - loss: 8.0059 - mean_absolute_error: 2.0713 - val_loss: 19.5351 - val_mean_absolute_error: 3.7984
# Epoch 95/200
# 26/26 [==============================] - 0s 3ms/step - loss: 8.1805 - mean_absolute_error: 2.1545 - val_loss: 26.6648 - val_mean_absolute_error: 4.4279
# Epoch 96/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.2472 - mean_absolute_error: 1.9845 - val_loss: 34.2227 - val_mean_absolute_error: 5.0664
# Epoch 97/200
# 26/26 [==============================] - 0s 5ms/step - loss: 6.8160 - mean_absolute_error: 1.9448 - val_loss: 15.4012 - val_mean_absolute_error: 3.3223
# Epoch 98/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.7305 - mean_absolute_error: 1.6809 - val_loss: 61.0105 - val_mean_absolute_error: 7.0257
# Epoch 99/200
# 26/26 [==============================] - 0s 3ms/step - loss: 16.5652 - mean_absolute_error: 3.1273 - val_loss: 27.8052 - val_mean_absolute_error: 4.5300
# Epoch 100/200
# 26/26 [==============================] - 0s 3ms/step - loss: 15.9180 - mean_absolute_error: 3.0728 - val_loss: 14.9312 - val_mean_absolute_error: 3.0136
# Epoch 101/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.6018 - mean_absolute_error: 1.6369 - val_loss: 23.7443 - val_mean_absolute_error: 4.1749
# Epoch 102/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.5655 - mean_absolute_error: 1.7904 - val_loss: 17.7448 - val_mean_absolute_error: 3.2267
# Epoch 103/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.4467 - mean_absolute_error: 1.6255 - val_loss: 13.5749 - val_mean_absolute_error: 3.0592
# Epoch 104/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.5951 - mean_absolute_error: 1.6657 - val_loss: 15.4052 - val_mean_absolute_error: 3.3275
# Epoch 105/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.3982 - mean_absolute_error: 1.6525 - val_loss: 24.9205 - val_mean_absolute_error: 3.9191
# Epoch 106/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.7156 - mean_absolute_error: 2.4655 - val_loss: 13.4996 - val_mean_absolute_error: 2.9221
# Epoch 107/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.8962 - mean_absolute_error: 1.7031 - val_loss: 17.1523 - val_mean_absolute_error: 3.5441
# Epoch 108/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.4031 - mean_absolute_error: 1.6115 - val_loss: 19.7152 - val_mean_absolute_error: 3.4035
# Epoch 109/200
# 26/26 [==============================] - 0s 6ms/step - loss: 7.3474 - mean_absolute_error: 1.9790 - val_loss: 23.4915 - val_mean_absolute_error: 3.7817
# Epoch 110/200
# 26/26 [==============================] - 0s 5ms/step - loss: 9.0764 - mean_absolute_error: 2.2665 - val_loss: 13.3006 - val_mean_absolute_error: 3.0147
# Epoch 111/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.3268 - mean_absolute_error: 1.6658 - val_loss: 13.2019 - val_mean_absolute_error: 2.9152
# Epoch 112/200
# 26/26 [==============================] - 0s 4ms/step - loss: 4.9561 - mean_absolute_error: 1.5721 - val_loss: 14.0953 - val_mean_absolute_error: 3.1661
# Epoch 113/200
# 26/26 [==============================] - 0s 7ms/step - loss: 5.2066 - mean_absolute_error: 1.5856 - val_loss: 13.6186 - val_mean_absolute_error: 3.0915
# Epoch 114/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.1649 - mean_absolute_error: 1.5784 - val_loss: 13.4989 - val_mean_absolute_error: 3.0782
# Epoch 115/200
# 26/26 [==============================] - 0s 5ms/step - loss: 6.9888 - mean_absolute_error: 1.9269 - val_loss: 17.4708 - val_mean_absolute_error: 3.5845
# Epoch 116/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.1611 - mean_absolute_error: 1.5771 - val_loss: 17.1261 - val_mean_absolute_error: 3.5477
# Epoch 117/200
# 26/26 [==============================] - 0s 7ms/step - loss: 5.1120 - mean_absolute_error: 1.5803 - val_loss: 28.1815 - val_mean_absolute_error: 4.2359
# Epoch 118/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.1754 - mean_absolute_error: 2.3988 - val_loss: 13.9076 - val_mean_absolute_error: 2.9354
# Epoch 119/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.5144 - mean_absolute_error: 1.6633 - val_loss: 19.7317 - val_mean_absolute_error: 3.4015
# Epoch 120/200
# 26/26 [==============================] - 0s 6ms/step - loss: 5.6823 - mean_absolute_error: 1.6641 - val_loss: 12.9715 - val_mean_absolute_error: 2.9542
# Epoch 121/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.4909 - mean_absolute_error: 1.6168 - val_loss: 15.2198 - val_mean_absolute_error: 3.3323
# Epoch 122/200
# 26/26 [==============================] - 0s 4ms/step - loss: 6.2686 - mean_absolute_error: 1.8211 - val_loss: 35.2362 - val_mean_absolute_error: 4.8947
# Epoch 123/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.6976 - mean_absolute_error: 2.0338 - val_loss: 13.7137 - val_mean_absolute_error: 3.1080
# Epoch 124/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.7646 - mean_absolute_error: 1.7001 - val_loss: 13.1806 - val_mean_absolute_error: 2.9044
# Epoch 125/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.6988 - mean_absolute_error: 1.7016 - val_loss: 14.3534 - val_mean_absolute_error: 2.9616
# Epoch 126/200
# 26/26 [==============================] - 0s 5ms/step - loss: 6.4316 - mean_absolute_error: 1.8092 - val_loss: 18.5196 - val_mean_absolute_error: 3.2925
# Epoch 127/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.5771 - mean_absolute_error: 1.6729 - val_loss: 51.8029 - val_mean_absolute_error: 6.2535
# Epoch 128/200
# 26/26 [==============================] - 0s 8ms/step - loss: 16.0420 - mean_absolute_error: 3.1220 - val_loss: 21.5755 - val_mean_absolute_error: 3.5891
# Epoch 129/200
# 26/26 [==============================] - 0s 7ms/step - loss: 8.0872 - mean_absolute_error: 2.0782 - val_loss: 16.4348 - val_mean_absolute_error: 3.1043
# Epoch 130/200
# 26/26 [==============================] - 0s 6ms/step - loss: 4.8413 - mean_absolute_error: 1.5405 - val_loss: 12.9611 - val_mean_absolute_error: 2.9229
# Epoch 131/200
# 26/26 [==============================] - 0s 6ms/step - loss: 4.9741 - mean_absolute_error: 1.5609 - val_loss: 14.4872 - val_mean_absolute_error: 3.2263
# Epoch 132/200
# 26/26 [==============================] - 0s 10ms/step - loss: 5.3051 - mean_absolute_error: 1.6254 - val_loss: 25.0658 - val_mean_absolute_error: 4.2869
# Epoch 133/200
# 26/26 [==============================] - 0s 4ms/step - loss: 6.4668 - mean_absolute_error: 1.8439 - val_loss: 13.5557 - val_mean_absolute_error: 2.9182
# Epoch 134/200
# 26/26 [==============================] - 0s 3ms/step - loss: 4.7470 - mean_absolute_error: 1.5354 - val_loss: 13.0897 - val_mean_absolute_error: 2.8983
# Epoch 135/200
# 26/26 [==============================] - 0s 3ms/step - loss: 4.8237 - mean_absolute_error: 1.5690 - val_loss: 41.1876 - val_mean_absolute_error: 5.3952
# Epoch 136/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.9452 - mean_absolute_error: 2.0553 - val_loss: 24.7424 - val_mean_absolute_error: 3.9148
# Epoch 137/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.8833 - mean_absolute_error: 2.0823 - val_loss: 30.5372 - val_mean_absolute_error: 4.4631
# Epoch 138/200
# 26/26 [==============================] - 0s 3ms/step - loss: 7.3261 - mean_absolute_error: 2.0170 - val_loss: 12.8970 - val_mean_absolute_error: 2.9332
# Epoch 139/200
# 26/26 [==============================] - 0s 6ms/step - loss: 5.6561 - mean_absolute_error: 1.7005 - val_loss: 17.2690 - val_mean_absolute_error: 3.5634
# Epoch 140/200
# 26/26 [==============================] - 0s 5ms/step - loss: 6.7440 - mean_absolute_error: 1.8796 - val_loss: 13.0435 - val_mean_absolute_error: 2.9817
# Epoch 141/200
# 26/26 [==============================] - 0s 4ms/step - loss: 6.9929 - mean_absolute_error: 1.9497 - val_loss: 51.4093 - val_mean_absolute_error: 6.2208
# Epoch 142/200
# 26/26 [==============================] - 0s 3ms/step - loss: 9.0492 - mean_absolute_error: 2.1753 - val_loss: 15.5458 - val_mean_absolute_error: 3.0400
# Epoch 143/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.0999 - mean_absolute_error: 1.5597 - val_loss: 22.0957 - val_mean_absolute_error: 3.6447
# Epoch 144/200
# 26/26 [==============================] - 0s 10ms/step - loss: 6.4966 - mean_absolute_error: 1.8276 - val_loss: 12.8797 - val_mean_absolute_error: 2.9132
# Epoch 145/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.7873 - mean_absolute_error: 1.6993 - val_loss: 13.9646 - val_mean_absolute_error: 2.9397
# Epoch 146/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.3955 - mean_absolute_error: 1.6303 - val_loss: 25.9590 - val_mean_absolute_error: 4.0306
# Epoch 147/200
# 26/26 [==============================] - 0s 5ms/step - loss: 7.5674 - mean_absolute_error: 2.0101 - val_loss: 13.3646 - val_mean_absolute_error: 2.9089
# Epoch 148/200
# 26/26 [==============================] - 0s 7ms/step - loss: 4.9056 - mean_absolute_error: 1.5552 - val_loss: 15.2589 - val_mean_absolute_error: 3.3374
# Epoch 149/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.6635 - mean_absolute_error: 1.6931 - val_loss: 14.3561 - val_mean_absolute_error: 3.2145
# Epoch 150/200
# 26/26 [==============================] - 0s 6ms/step - loss: 6.0128 - mean_absolute_error: 1.7759 - val_loss: 13.5364 - val_mean_absolute_error: 3.0917
# Epoch 151/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.1779 - mean_absolute_error: 1.5844 - val_loss: 16.5846 - val_mean_absolute_error: 3.1288
# Epoch 152/200
# 26/26 [==============================] - 0s 4ms/step - loss: 6.2791 - mean_absolute_error: 1.8464 - val_loss: 15.1218 - val_mean_absolute_error: 3.3191
# Epoch 153/200
# 26/26 [==============================] - 0s 10ms/step - loss: 6.1063 - mean_absolute_error: 1.7645 - val_loss: 17.5634 - val_mean_absolute_error: 3.5913
# Epoch 154/200
# 26/26 [==============================] - 0s 7ms/step - loss: 5.3978 - mean_absolute_error: 1.6656 - val_loss: 15.5585 - val_mean_absolute_error: 3.3758
# Epoch 155/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.9795 - mean_absolute_error: 1.7335 - val_loss: 14.4006 - val_mean_absolute_error: 2.9628
# Epoch 156/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.0345 - mean_absolute_error: 1.7762 - val_loss: 12.7371 - val_mean_absolute_error: 2.9205
# Epoch 157/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.4257 - mean_absolute_error: 1.6398 - val_loss: 36.2045 - val_mean_absolute_error: 5.2161
# Epoch 158/200
# 26/26 [==============================] - 0s 7ms/step - loss: 10.2719 - mean_absolute_error: 2.4307 - val_loss: 13.0559 - val_mean_absolute_error: 2.9041
# Epoch 159/200
# 26/26 [==============================] - 0s 12ms/step - loss: 7.2399 - mean_absolute_error: 1.9736 - val_loss: 13.0131 - val_mean_absolute_error: 2.9880
# Epoch 160/200
# 26/26 [==============================] - 0s 9ms/step - loss: 4.7062 - mean_absolute_error: 1.5136 - val_loss: 17.5571 - val_mean_absolute_error: 3.2112
# Epoch 161/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.5042 - mean_absolute_error: 1.6733 - val_loss: 14.6586 - val_mean_absolute_error: 3.2584
# Epoch 162/200
# 26/26 [==============================] - 0s 6ms/step - loss: 4.9833 - mean_absolute_error: 1.5658 - val_loss: 42.6828 - val_mean_absolute_error: 5.7097
# Epoch 163/200
# 26/26 [==============================] - 0s 6ms/step - loss: 9.4543 - mean_absolute_error: 2.2823 - val_loss: 14.4119 - val_mean_absolute_error: 3.2194
# Epoch 164/200
# 26/26 [==============================] - 0s 8ms/step - loss: 4.8640 - mean_absolute_error: 1.5496 - val_loss: 13.3374 - val_mean_absolute_error: 2.9094
# Epoch 165/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.7650 - mean_absolute_error: 1.7128 - val_loss: 12.9728 - val_mean_absolute_error: 2.9851
# Epoch 166/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.8752 - mean_absolute_error: 1.7223 - val_loss: 26.9116 - val_mean_absolute_error: 4.1239
# Epoch 167/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.3610 - mean_absolute_error: 1.8256 - val_loss: 12.8169 - val_mean_absolute_error: 2.9259
# Epoch 168/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.0844 - mean_absolute_error: 1.5978 - val_loss: 13.3254 - val_mean_absolute_error: 3.0510
# Epoch 169/200
# 26/26 [==============================] - 0s 4ms/step - loss: 6.3616 - mean_absolute_error: 1.7890 - val_loss: 55.9150 - val_mean_absolute_error: 6.6941
# Epoch 170/200
# 26/26 [==============================] - 0s 5ms/step - loss: 12.0915 - mean_absolute_error: 2.6007 - val_loss: 12.9630 - val_mean_absolute_error: 2.9506
# Epoch 171/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.0518 - mean_absolute_error: 1.5512 - val_loss: 28.2180 - val_mean_absolute_error: 4.2418
# Epoch 172/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.7744 - mean_absolute_error: 2.4868 - val_loss: 15.4684 - val_mean_absolute_error: 3.0339
# Epoch 173/200
# 26/26 [==============================] - 0s 6ms/step - loss: 5.0587 - mean_absolute_error: 1.5486 - val_loss: 13.1723 - val_mean_absolute_error: 2.9078
# Epoch 174/200
# 26/26 [==============================] - 0s 4ms/step - loss: 7.6303 - mean_absolute_error: 2.0860 - val_loss: 13.3136 - val_mean_absolute_error: 3.0350
# Epoch 175/200
# 26/26 [==============================] - 0s 7ms/step - loss: 5.3812 - mean_absolute_error: 1.6262 - val_loss: 30.7678 - val_mean_absolute_error: 4.7756
# Epoch 176/200
# 26/26 [==============================] - 0s 5ms/step - loss: 8.3041 - mean_absolute_error: 2.1551 - val_loss: 29.4576 - val_mean_absolute_error: 4.6614
# Epoch 177/200
# 26/26 [==============================] - 0s 7ms/step - loss: 11.2266 - mean_absolute_error: 2.5760 - val_loss: 13.8357 - val_mean_absolute_error: 3.1271
# Epoch 178/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.2019 - mean_absolute_error: 1.7875 - val_loss: 14.4008 - val_mean_absolute_error: 3.2162
# Epoch 179/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.9359 - mean_absolute_error: 1.7477 - val_loss: 15.2062 - val_mean_absolute_error: 3.3289
# Epoch 180/200
# 26/26 [==============================] - 0s 4ms/step - loss: 7.0191 - mean_absolute_error: 1.8595 - val_loss: 23.6359 - val_mean_absolute_error: 4.1662
# Epoch 181/200
# 26/26 [==============================] - 0s 5ms/step - loss: 6.3457 - mean_absolute_error: 1.8275 - val_loss: 14.5013 - val_mean_absolute_error: 3.2343
# Epoch 182/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.0992 - mean_absolute_error: 1.5809 - val_loss: 19.6528 - val_mean_absolute_error: 3.8099
# Epoch 183/200
# 26/26 [==============================] - 0s 5ms/step - loss: 7.0976 - mean_absolute_error: 1.9368 - val_loss: 13.0507 - val_mean_absolute_error: 2.9039
# Epoch 184/200
# 26/26 [==============================] - 0s 7ms/step - loss: 4.9433 - mean_absolute_error: 1.5518 - val_loss: 13.3171 - val_mean_absolute_error: 2.9105
# Epoch 185/200
# 26/26 [==============================] - 0s 7ms/step - loss: 4.7391 - mean_absolute_error: 1.5098 - val_loss: 12.7856 - val_mean_absolute_error: 2.9500
# Epoch 186/200
# 26/26 [==============================] - 0s 6ms/step - loss: 5.3574 - mean_absolute_error: 1.6381 - val_loss: 15.3628 - val_mean_absolute_error: 3.0301
# Epoch 187/200
# 26/26 [==============================] - 0s 5ms/step - loss: 7.8599 - mean_absolute_error: 2.1398 - val_loss: 13.2651 - val_mean_absolute_error: 3.0361
# Epoch 188/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.6128 - mean_absolute_error: 1.8920 - val_loss: 16.9752 - val_mean_absolute_error: 3.1581
# Epoch 189/200
# 26/26 [==============================] - 0s 8ms/step - loss: 5.7904 - mean_absolute_error: 1.7206 - val_loss: 16.0202 - val_mean_absolute_error: 3.0785
# Epoch 190/200
# 26/26 [==============================] - 0s 3ms/step - loss: 5.1694 - mean_absolute_error: 1.5806 - val_loss: 19.7209 - val_mean_absolute_error: 3.4106
# Epoch 191/200
# 26/26 [==============================] - 0s 3ms/step - loss: 9.4081 - mean_absolute_error: 2.3377 - val_loss: 13.5165 - val_mean_absolute_error: 2.9163
# Epoch 192/200
# 26/26 [==============================] - 0s 4ms/step - loss: 7.0786 - mean_absolute_error: 1.9121 - val_loss: 13.8216 - val_mean_absolute_error: 2.9350
# Epoch 193/200
# 26/26 [==============================] - 0s 3ms/step - loss: 6.8427 - mean_absolute_error: 1.8963 - val_loss: 25.7579 - val_mean_absolute_error: 4.0107
# Epoch 194/200
# 26/26 [==============================] - 0s 7ms/step - loss: 7.8675 - mean_absolute_error: 2.0582 - val_loss: 19.0077 - val_mean_absolute_error: 3.3344
# Epoch 195/200
# 26/26 [==============================] - 0s 6ms/step - loss: 5.8536 - mean_absolute_error: 1.6929 - val_loss: 19.7082 - val_mean_absolute_error: 3.4014
# Epoch 196/200
# 26/26 [==============================] - 0s 5ms/step - loss: 5.3624 - mean_absolute_error: 1.6491 - val_loss: 13.2066 - val_mean_absolute_error: 3.0299
# Epoch 197/200
# 26/26 [==============================] - 0s 4ms/step - loss: 5.4799 - mean_absolute_error: 1.6497 - val_loss: 12.7721 - val_mean_absolute_error: 2.9278
# Epoch 198/200
# 26/26 [==============================] - 0s 6ms/step - loss: 5.0379 - mean_absolute_error: 1.5574 - val_loss: 12.8883 - val_mean_absolute_error: 2.9755
# Epoch 199/200
# 26/26 [==============================] - 0s 5ms/step - loss: 7.7691 - mean_absolute_error: 2.0426 - val_loss: 44.8926 - val_mean_absolute_error: 5.8730
# Epoch 200/200
# 26/26 [==============================] - 0s 3ms/step - loss: 10.2864 - mean_absolute_error: 2.3519 - val_loss: 13.4938 - val_mean_absolute_error: 3.0678

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 26/26 [==============================] - 0s 1ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
